# %%
from langchain_core.prompts import PromptTemplate

template =  """\
# Instricciones para el asistente de IA

Recuerda que hoy es {fecha_actual}

## Rol
Eres un experto en marketing digital con 10 años de experiencia.

## Tarea
Analiza el siguiente texto de un anuncio y proporciona 3 sugerencias para mejorarlo, enfocandote en el llamado a la accion.

## Texto del anuncio
{texto_anuncio}

## Formato de salida
- *Sugerencia 1:* [Tu primera sugerencia]
- *Sugerencia 2:* [Tu segunda sugerencia]
- *Sugerencia 3:* [Tu tercera sugerencia]
"""
prompt_template = PromptTemplate.from_template(template)
prompt = prompt_template.format(
    fecha_actual="15 de junio de 2024",
    texto_anuncio="Compra nuestro producto ahora y mejora tu vida."
)
print(prompt)
# Out:
# # Instricciones para el asistente de IA
#
# Recuerda que hoy es 15 de junio de 2024
#
# ## Rol
# Eres un experto en marketing digital con 10 años de experiencia.
#
# ## Tarea
# Analiza el siguiente texto de un anuncio y proporciona 3 sugerencias para mejorarlo, enfocandote en el llamado a la accion.
#
# ## Texto del anuncio
# Compra nuestro producto ahora y mejora tu vida.
#
# ## Formato de salida
# - *Sugerencia 1:* [Tu primera sugerencia]
# - *Sugerencia 2:* [Tu segunda sugerencia]
# - *Sugerencia 3:* [Tu tercera sugerencia]

# %%
import datetime

today = datetime.date.today().strftime("%d de %B de %Y")

prompt_template = PromptTemplate.from_template(template, partial_variables={
    "fecha_actual": today})

prompt = prompt_template.format(
    texto_anuncio="Compra nuestro producto ahora y mejora tu vida."
)

print(prompt)
# Out:
# # Instricciones para el asistente de IA
#
# Recuerda que hoy es 12 de November de 2025
#
# ## Rol
# Eres un experto en marketing digital con 10 años de experiencia.
#
# ## Tarea
# Analiza el siguiente texto de un anuncio y proporciona 3 sugerencias para mejorarlo, enfocandote en el llamado a la accion.
#
# ## Texto del anuncio
# Compra nuestro producto ahora y mejora tu vida.
#
# ## Formato de salida
# - *Sugerencia 1:* [Tu primera sugerencia]
# - *Sugerencia 2:* [Tu segunda sugerencia]
# - *Sugerencia 3:* [Tu tercera sugerencia]

# %%
template = """\
    Your are a helpful that responds to the user's message

    {% if name %}
    The user's name is {name} and you can call them by that name
    {% endif -%}
    
    the user's message is: {{user_message}}
"""

prompt_template = PromptTemplate.from_template(template, template_format="jinja2")

prompt = prompt_template.format(
    user_message="Hello, how are you?",
)

print(prompt)
# Out:
#     Your are a helpful that responds to the user's message
#
#     the user's message is: Hello, how are you?
