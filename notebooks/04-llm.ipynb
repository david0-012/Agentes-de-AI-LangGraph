# %%
import os

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

gemini25f_llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0)
response = gemini25f_llm.invoke("Hola, como estas?")
response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# ¡Hola! Estoy muy bien, gracias. ¿Y tú, cómo estás?

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

gemini25fl_llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite", temperature=0)
response = gemini25fl_llm.invoke("Hola, como estas?")
response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# ¡Hola! Estoy muy bien, gracias por preguntar. ¿Y tú, cómo estás?

# %%
from langchain_core.messages import AIMessage, HumanMessage, SystemMessage

msg_1 = SystemMessage(content="Eres un asistente de tareas útil")
msg_2 = HumanMessage(content="Me llamo Juan")
msg_3 = AIMessage(content="Hola Juan, como estas?")
msg_4 = HumanMessage(content="¿Como me llamo?")
history = [msg_1, msg_2, msg_3, msg_4]
response = gemini25fl_llm.invoke(history)
response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# Te llamas Juan.

# %%
from langchain.chat_models import init_chat_model

llm =init_chat_model("google_genai:gemini-2.5-flash-lite", temperature=0)
response = llm.invoke(history)
response.pretty_print()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 3
#       1 from langchain.chat_models import init_chat_model
# ----> 3 llm =init_chat_model("google-genai-chat:gemini-2.5-flash-lite", temperature=0)
#       4 response = llm.invoke(history)
#       5 response.pretty_print()
#
# File c:\Users\juan.casallas.p\Desktop\my_course_agent\.venv\Lib\site-packages\langchain\chat_models\base.py:284, in init_chat_model(model, model_provider, configurable_fields, config_prefix, **kwargs)
#     276     warnings.warn(
#     277         f"{config_prefix=} has been set but no fields are configurable. Set "
#     278         f"`configurable_fields=(...)` to specify the model params that are "
#     279         f"configurable.",
#     280         stacklevel=2,
#     281     )
#     283 if not configurable_fields:
# --> 284     return _init_chat_model_helper(
#     285         cast("str", model),
#     286         model_provider=model_provider,
#     287         **kwargs,
#     288     )
#     289 if model:
#     290     kwargs["model"] = model
#
# File c:\Users\juan.casallas.p\Desktop\my_course_agent\.venv\Lib\site-packages\langchain\chat_models\base.py:306, in _init_chat_model_helper(model, model_provider, **kwargs)
#     300 def _init_chat_model_helper(
#     301     model: str,
#     302     *,
#     303     model_provider: str | None = None,
#     304     **kwargs: Any,
#     305 ) -> BaseChatModel:
# --> 306     model, model_provider = _parse_model(model, model_provider)
#     307     if model_provider == "openai":
#     308         _check_pkg("langchain_openai")
#
# File c:\Users\juan.casallas.p\Desktop\my_course_agent\.venv\Lib\site-packages\langchain\chat_models\base.py:484, in _parse_model(model, model_provider)
#     480 if not model_provider:
#     481     msg = (
#     482         f"Unable to infer model provider for {model=}, please specify model_provider directly."
#     483     )
# --> 484     raise ValueError(msg)
#     485 model_provider = model_provider.replace("-", "_").lower()
#     486 return model, model_provider
#
# ValueError: Unable to infer model provider for model='google-genai-chat:gemini-2.5-flash-lite', please specify model_provider directly.
